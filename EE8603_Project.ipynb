# %% [markdown]
# <a href="https://colab.research.google.com/github/gillilandrocque/KneeToMe/blob/main/EE8603_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is the first option for the final project for EE8603. My student number ends in 1 thus I am doing the chess classification task.
#
# I will install the full version of pycaret as specified in the documentation

# %%
pip install pycaret[full]

# %%
import pandas as pd
from pycaret.classification import *

# import chess dataset and unzip the files, updating them if they don't exist
# !wget https://archive.ics.uci.edu/static/public/22/chess+king+rook+vs+king+pawn.zip -O chess.zip
# !unzip -u chess.zip

# the data is imported into a pandas data frame.

# By default there are no feature names, so the feature value list must be created.

# The feature value list is presented in kr-vs-kp.names, and describes the
#   state of the chess board via 36 attributes.

feature_value_list = ['bkblk','bknwy','bkon8','bkona','bkspr','bkxbq','bkxcr',
                      'bkxwp','blxwp','bxqsq','cntxt','dsopp','dwipd','hdchk',
                      'katri','mulch','qxmsq','r2ar8','reskd','reskr','rimmx',
                      'rkxwp','rxmsq','simpl','skach','skewr','skrxp','spcop',
                      'stlmt','thrsk','wkcti','wkna8','wknck','wkovl','wkpos',
                      'wtoeg', 'game_outcome']


chess_df = pd.read_csv("kr-vs-kp.data", names= feature_value_list)
print(chess_df)

# each attribute has a categorical value. To determine all the posisble values, a list is created to check the total number of categories
print('possible categories for each feature:')
char_seen = []
for i in range(len(feature_value_list)-1):
  for char in chess_df[feature_value_list[i]]:
    if char not in char_seen:
        char_seen.append(char)
print(''.join(char_seen))

# seeing as there are 4 categories possible, all of the data will be 1-hot-encoded by adding 6 sub attributes in place of the main attribute to form a boolean data representing the category.
# the categories for each attribute are either 'f', 't', 'l', 'g', 'n, 'w', or 'b'

# setup the experiment object with the chess data frame as the input data, and the game outcome as the target
experiment = ClassificationExperiment()
experiment.setup(chess_df, target= 'game_outcome')

# display transformed training data
experiment.get_config('X_train_transformed')

# compare models. This will compare all the models available in pycaret and return the model with the best metrics.
best_models = experiment.compare_models(sort= 'Accuracy', n_select= 3)
best_model = best_models[0]

# tuning the model hyperparameters for acccuracy
tuned_model = experiment.tune_model(best_model)

# these graphs display the metrics of the model. The confusion matrix, the area under the convergence curve, and a bar graph signifying the most important features.
experiment.plot_model(tuned_model, plot = 'confusion_matrix')
experiment.plot_model(tuned_model, plot = 'auc')
experiment.plot_model(tuned_model, plot = 'feature_all')

# using the results of this, we can drop

# now that the network is created and trained, we can use the best result from the model comparison to evaluate the test data that was withheld from the training during the test-train split
prediction_df = experiment.predict_model(best_model)

# lets try this with an ensemble model, blending the top 3 models with the best accuracy


# blend top 3 models
experiment_blended = experiment.blend_models(best_models, )

# stack top 3 models
experiment_stacked = experiment.stack_models(best_models)

# predictions on the blended and stacked models
experiment_blended_predictions = experiment.predict_model(experiment_blended)
experiment_stacked_predictions = experiment.predict_model(experiment_stacked)
# Out:
# --2023-11-29 21:03:15--  https://archive.ics.uci.edu/static/public/22/chess+king+rook+vs+king+pawn.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘chess.zip’
#
# chess.zip               [ <=>                ]  13.52K  --.-KB/s    in 0.03s
#
# 2023-11-29 21:03:15 (425 KB/s) - ‘chess.zip’ saved [13844]
#
# Archive:  chess.zip
#      bkblk bknwy bkon8 bkona bkspr bkxbq bkxcr bkxwp blxwp bxqsq  ... spcop  \
# 0        f     f     f     f     f     f     f     f     f     f  ...     f
# 1        f     f     f     f     t     f     f     f     f     f  ...     f
# 2        f     f     f     f     t     f     t     f     f     f  ...     f
# 3        f     f     f     f     f     f     f     f     t     f  ...     f
# 4        f     f     f     f     f     f     f     f     f     f  ...     f
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 3191     t     f     f     f     f     f     t     f     f     f  ...     f
# 3192     t     f     f     f     f     f     t     f     f     f  ...     f
# 3193     t     f     f     f     f     f     t     f     f     f  ...     f
# 3194     t     f     t     f     f     f     t     f     f     f  ...     f
# 3195     t     f     t     f     f     f     t     f     f     f  ...     f
#
#      stlmt thrsk wkcti wkna8 wknck wkovl wkpos wtoeg game_outcome
# 0        f     f     f     f     f     t     t     n          won
# 1        f     f     f     f     f     t     t     n          won
# 2        f     f     f     f     f     t     t     n          won
# 3        f     f     f     f     f     t     t     n          won
# 4        f     f     f     f     f     t     t     n          won
# ...    ...   ...   ...   ...   ...   ...   ...   ...          ...
# 3191     t     f     f     t     f     t     f     n        nowin
# 3192     t     f     f     t     f     t     f     n        nowin
# 3193     t     f     f     t     f     t     f     n        nowin
# 3194     t     f     f     t     f     f     f     n        nowin
# 3195     t     f     f     t     f     f     f     n        nowin
#
# [3196 rows x 37 columns]
# possible categories for each feature:
# ftlgnwb
# <style type="text/css">
# #T_dbc34_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_dbc34" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dbc34_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_dbc34_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbc34_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dbc34_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_dbc34_row0_col1" class="data row0 col1" >5383</td>
#     </tr>
#     <tr>
#       <th id="T_dbc34_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dbc34_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_dbc34_row1_col1" class="data row1 col1" >game_outcome</td>
#     </tr>
#     <tr>
#       <th id="T_dbc34_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dbc34_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_dbc34_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_dbc34_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dbc34_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_dbc34_row3_col1" class="data row3 col1" >nowin: 0, won: 1</td>
#     </tr>
#     <tr>
#       <th id="T_dbc34_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dbc34_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_dbc34_row4_col1" class="data row4 col1" >(3196, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_dbc34_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dbc34_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_dbc34_row5_col1" class="data row5 col1" >(3196, 39)</td>
#     </tr>
#     <tr>
#       <th id="T_dbc34_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dbc34_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_dbc34_row6_col1" class="data row6 col1" >(2237, 39)</td>
#     </tr>
#     <tr>
#       <th id="T_dbc34_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dbc34_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_dbc34_row7_col1" class="data row7 col1" >(959, 39)</td>
#     </tr>
#     <tr>
#       <th id="T_dbc34_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dbc34_row8_col0" class="data row8 col0" >Ordinal features</td>
#       <td id="T_dbc34_row8_col1" class="data row8 col1" >35</td>
#     </tr>
#     <tr>
#       <th id="T_dbc34_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dbc34_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_dbc34_row9_col1" class="data row9 col1" >36</td>
#     </tr>
#     <tr>
#       <th id="T_dbc34_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_dbc34_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_dbc34_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_dbc34_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_dbc34_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_dbc34_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_dbc34_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_dbc34_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_dbc34_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_dbc34_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_dbc34_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_dbc34_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_dbc34_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_dbc34_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_dbc34_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_dbc34_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_dbc34_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_dbc34_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_dbc34_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_dbc34_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_dbc34_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_dbc34_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_dbc34_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_dbc34_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_dbc34_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_dbc34_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_dbc34_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_dbc34_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_dbc34_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_dbc34_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_dbc34_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_dbc34_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_dbc34_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_dbc34_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_dbc34_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_dbc34_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_dbc34_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_dbc34_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_dbc34_row22_col1" class="data row22 col1" >4863</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_3b1eb th {
#   text-align: left;
# }
# #T_3b1eb_row0_col0, #T_3b1eb_row0_col2, #T_3b1eb_row1_col0, #T_3b1eb_row1_col1, #T_3b1eb_row1_col2, #T_3b1eb_row1_col3, #T_3b1eb_row1_col4, #T_3b1eb_row1_col5, #T_3b1eb_row1_col6, #T_3b1eb_row1_col7, #T_3b1eb_row2_col0, #T_3b1eb_row2_col1, #T_3b1eb_row2_col3, #T_3b1eb_row2_col4, #T_3b1eb_row2_col5, #T_3b1eb_row2_col6, #T_3b1eb_row2_col7, #T_3b1eb_row3_col0, #T_3b1eb_row3_col1, #T_3b1eb_row3_col2, #T_3b1eb_row3_col3, #T_3b1eb_row3_col4, #T_3b1eb_row3_col5, #T_3b1eb_row3_col6, #T_3b1eb_row3_col7, #T_3b1eb_row4_col0, #T_3b1eb_row4_col1, #T_3b1eb_row4_col2, #T_3b1eb_row4_col3, #T_3b1eb_row4_col4, #T_3b1eb_row4_col5, #T_3b1eb_row4_col6, #T_3b1eb_row4_col7, #T_3b1eb_row5_col0, #T_3b1eb_row5_col1, #T_3b1eb_row5_col2, #T_3b1eb_row5_col3, #T_3b1eb_row5_col4, #T_3b1eb_row5_col5, #T_3b1eb_row5_col6, #T_3b1eb_row5_col7, #T_3b1eb_row6_col0, #T_3b1eb_row6_col1, #T_3b1eb_row6_col2, #T_3b1eb_row6_col3, #T_3b1eb_row6_col4, #T_3b1eb_row6_col5, #T_3b1eb_row6_col6, #T_3b1eb_row6_col7, #T_3b1eb_row7_col0, #T_3b1eb_row7_col1, #T_3b1eb_row7_col2, #T_3b1eb_row7_col3, #T_3b1eb_row7_col4, #T_3b1eb_row7_col5, #T_3b1eb_row7_col6, #T_3b1eb_row7_col7, #T_3b1eb_row8_col0, #T_3b1eb_row8_col1, #T_3b1eb_row8_col2, #T_3b1eb_row8_col3, #T_3b1eb_row8_col4, #T_3b1eb_row8_col5, #T_3b1eb_row8_col6, #T_3b1eb_row8_col7, #T_3b1eb_row9_col0, #T_3b1eb_row9_col1, #T_3b1eb_row9_col2, #T_3b1eb_row9_col3, #T_3b1eb_row9_col4, #T_3b1eb_row9_col5, #T_3b1eb_row9_col6, #T_3b1eb_row9_col7, #T_3b1eb_row10_col0, #T_3b1eb_row10_col1, #T_3b1eb_row10_col2, #T_3b1eb_row10_col3, #T_3b1eb_row10_col4, #T_3b1eb_row10_col5, #T_3b1eb_row10_col6, #T_3b1eb_row10_col7, #T_3b1eb_row11_col0, #T_3b1eb_row11_col1, #T_3b1eb_row11_col2, #T_3b1eb_row11_col3, #T_3b1eb_row11_col4, #T_3b1eb_row11_col5, #T_3b1eb_row11_col6, #T_3b1eb_row11_col7, #T_3b1eb_row12_col0, #T_3b1eb_row12_col1, #T_3b1eb_row12_col2, #T_3b1eb_row12_col3, #T_3b1eb_row12_col4, #T_3b1eb_row12_col5, #T_3b1eb_row12_col6, #T_3b1eb_row12_col7, #T_3b1eb_row13_col0, #T_3b1eb_row13_col1, #T_3b1eb_row13_col2, #T_3b1eb_row13_col3, #T_3b1eb_row13_col4, #T_3b1eb_row13_col5, #T_3b1eb_row13_col6, #T_3b1eb_row13_col7, #T_3b1eb_row14_col0, #T_3b1eb_row14_col1, #T_3b1eb_row14_col2, #T_3b1eb_row14_col3, #T_3b1eb_row14_col4, #T_3b1eb_row14_col5, #T_3b1eb_row14_col6, #T_3b1eb_row14_col7, #T_3b1eb_row15_col0, #T_3b1eb_row15_col1, #T_3b1eb_row15_col2, #T_3b1eb_row15_col3, #T_3b1eb_row15_col4, #T_3b1eb_row15_col5, #T_3b1eb_row15_col6, #T_3b1eb_row15_col7 {
#   text-align: left;
# }
# #T_3b1eb_row0_col1, #T_3b1eb_row0_col3, #T_3b1eb_row0_col4, #T_3b1eb_row0_col5, #T_3b1eb_row0_col6, #T_3b1eb_row0_col7, #T_3b1eb_row2_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3b1eb_row0_col8, #T_3b1eb_row1_col8, #T_3b1eb_row2_col8, #T_3b1eb_row3_col8, #T_3b1eb_row4_col8, #T_3b1eb_row5_col8, #T_3b1eb_row6_col8, #T_3b1eb_row7_col8, #T_3b1eb_row8_col8, #T_3b1eb_row10_col8, #T_3b1eb_row11_col8, #T_3b1eb_row12_col8, #T_3b1eb_row13_col8, #T_3b1eb_row14_col8, #T_3b1eb_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_3b1eb_row9_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_3b1eb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b1eb_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3b1eb_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3b1eb_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3b1eb_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3b1eb_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3b1eb_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3b1eb_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3b1eb_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_3b1eb_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b1eb_level0_row0" class="row_heading level0 row0" >dt</th>
#       <td id="T_3b1eb_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_3b1eb_row0_col1" class="data row0 col1" >0.9964</td>
#       <td id="T_3b1eb_row0_col2" class="data row0 col2" >0.9964</td>
#       <td id="T_3b1eb_row0_col3" class="data row0 col3" >0.9964</td>
#       <td id="T_3b1eb_row0_col4" class="data row0 col4" >0.9964</td>
#       <td id="T_3b1eb_row0_col5" class="data row0 col5" >0.9964</td>
#       <td id="T_3b1eb_row0_col6" class="data row0 col6" >0.9928</td>
#       <td id="T_3b1eb_row0_col7" class="data row0 col7" >0.9928</td>
#       <td id="T_3b1eb_row0_col8" class="data row0 col8" >0.5210</td>
#     </tr>
#     <tr>
#       <th id="T_3b1eb_level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_3b1eb_row1_col0" class="data row1 col0" >CatBoost Classifier</td>
#       <td id="T_3b1eb_row1_col1" class="data row1 col1" >0.9951</td>
#       <td id="T_3b1eb_row1_col2" class="data row1 col2" >0.9992</td>
#       <td id="T_3b1eb_row1_col3" class="data row1 col3" >0.9951</td>
#       <td id="T_3b1eb_row1_col4" class="data row1 col4" >0.9951</td>
#       <td id="T_3b1eb_row1_col5" class="data row1 col5" >0.9951</td>
#       <td id="T_3b1eb_row1_col6" class="data row1 col6" >0.9901</td>
#       <td id="T_3b1eb_row1_col7" class="data row1 col7" >0.9902</td>
#       <td id="T_3b1eb_row1_col8" class="data row1 col8" >4.9490</td>
#     </tr>
#     <tr>
#       <th id="T_3b1eb_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_3b1eb_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_3b1eb_row2_col1" class="data row2 col1" >0.9928</td>
#       <td id="T_3b1eb_row2_col2" class="data row2 col2" >0.9994</td>
#       <td id="T_3b1eb_row2_col3" class="data row2 col3" >0.9928</td>
#       <td id="T_3b1eb_row2_col4" class="data row2 col4" >0.9929</td>
#       <td id="T_3b1eb_row2_col5" class="data row2 col5" >0.9928</td>
#       <td id="T_3b1eb_row2_col6" class="data row2 col6" >0.9856</td>
#       <td id="T_3b1eb_row2_col7" class="data row2 col7" >0.9857</td>
#       <td id="T_3b1eb_row2_col8" class="data row2 col8" >1.0890</td>
#     </tr>
#     <tr>
#       <th id="T_3b1eb_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_3b1eb_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_3b1eb_row3_col1" class="data row3 col1" >0.9920</td>
#       <td id="T_3b1eb_row3_col2" class="data row3 col2" >0.9987</td>
#       <td id="T_3b1eb_row3_col3" class="data row3 col3" >0.9920</td>
#       <td id="T_3b1eb_row3_col4" class="data row3 col4" >0.9920</td>
#       <td id="T_3b1eb_row3_col5" class="data row3 col5" >0.9919</td>
#       <td id="T_3b1eb_row3_col6" class="data row3 col6" >0.9839</td>
#       <td id="T_3b1eb_row3_col7" class="data row3 col7" >0.9840</td>
#       <td id="T_3b1eb_row3_col8" class="data row3 col8" >0.7600</td>
#     </tr>
#     <tr>
#       <th id="T_3b1eb_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_3b1eb_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_3b1eb_row4_col1" class="data row4 col1" >0.9919</td>
#       <td id="T_3b1eb_row4_col2" class="data row4 col2" >0.9993</td>
#       <td id="T_3b1eb_row4_col3" class="data row4 col3" >0.9919</td>
#       <td id="T_3b1eb_row4_col4" class="data row4 col4" >0.9920</td>
#       <td id="T_3b1eb_row4_col5" class="data row4 col5" >0.9919</td>
#       <td id="T_3b1eb_row4_col6" class="data row4 col6" >0.9839</td>
#       <td id="T_3b1eb_row4_col7" class="data row4 col7" >0.9839</td>
#       <td id="T_3b1eb_row4_col8" class="data row4 col8" >0.7830</td>
#     </tr>
#     <tr>
#       <th id="T_3b1eb_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_3b1eb_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_3b1eb_row5_col1" class="data row5 col1" >0.9911</td>
#       <td id="
# Processing:   0%|          | 0/71 [00:00<?, ?it/s]
# <style type="text/css">
# #T_76115_row10_col0, #T_76115_row10_col1, #T_76115_row10_col2, #T_76115_row10_col3, #T_76115_row10_col4, #T_76115_row10_col5, #T_76115_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_76115" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76115_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_76115_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_76115_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_76115_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_76115_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_76115_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_76115_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76115_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76115_row0_col0" class="data row0 col0" >0.9821</td>
#       <td id="T_76115_row0_col1" class="data row0 col1" >0.9914</td>
#       <td id="T_76115_row0_col2" class="data row0 col2" >0.9821</td>
#       <td id="T_76115_row0_col3" class="data row0 col3" >0.9823</td>
#       <td id="T_76115_row0_col4" class="data row0 col4" >0.9821</td>
#       <td id="T_76115_row0_col5" class="data row0 col5" >0.9642</td>
#       <td id="T_76115_row0_col6" class="data row0 col6" >0.9644</td>
#     </tr>
#     <tr>
#       <th id="T_76115_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_76115_row1_col0" class="data row1 col0" >0.9554</td>
#       <td id="T_76115_row1_col1" class="data row1 col1" >0.9787</td>
#       <td id="T_76115_row1_col2" class="data row1 col2" >0.9554</td>
#       <td id="T_76115_row1_col3" class="data row1 col3" >0.9568</td>
#       <td id="T_76115_row1_col4" class="data row1 col4" >0.9554</td>
#       <td id="T_76115_row1_col5" class="data row1 col5" >0.9107</td>
#       <td id="T_76115_row1_col6" class="data row1 col6" >0.9121</td>
#     </tr>
#     <tr>
#       <th id="T_76115_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_76115_row2_col0" class="data row2 col0" >0.9554</td>
#       <td id="T_76115_row2_col1" class="data row2 col1" >0.9869</td>
#       <td id="T_76115_row2_col2" class="data row2 col2" >0.9554</td>
#       <td id="T_76115_row2_col3" class="data row2 col3" >0.9555</td>
#       <td id="T_76115_row2_col4" class="data row2 col4" >0.9554</td>
#       <td id="T_76115_row2_col5" class="data row2 col5" >0.9106</td>
#       <td id="T_76115_row2_col6" class="data row2 col6" >0.9108</td>
#     </tr>
#     <tr>
#       <th id="T_76115_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_76115_row3_col0" class="data row3 col0" >0.9241</td>
#       <td id="T_76115_row3_col1" class="data row3 col1" >0.9749</td>
#       <td id="T_76115_row3_col2" class="data row3 col2" >0.9241</td>
#       <td id="T_76115_row3_col3" class="data row3 col3" >0.9271</td>
#       <td id="T_76115_row3_col4" class="data row3 col4" >0.9241</td>
#       <td id="T_76115_row3_col5" class="data row3 col5" >0.8485</td>
#       <td id="T_76115_row3_col6" class="data row3 col6" >0.8512</td>
#     </tr>
#     <tr>
#       <th id="T_76115_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_76115_row4_col0" class="data row4 col0" >0.9062</td>
#       <td id="T_76115_row4_col1" class="data row4 col1" >0.9646</td>
#       <td id="T_76115_row4_col2" class="data row4 col2" >0.9062</td>
#       <td id="T_76115_row4_col3" class="data row4 col3" >0.9122</td>
#       <td id="T_76115_row4_col4" class="data row4 col4" >0.9062</td>
#       <td id="T_76115_row4_col5" class="data row4 col5" >0.8131</td>
#       <td id="T_76115_row4_col6" class="data row4 col6" >0.8186</td>
#     </tr>
#     <tr>
#       <th id="T_76115_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_76115_row5_col0" class="data row5 col0" >0.9330</td>
#       <td id="T_76115_row5_col1" class="data row5 col1" >0.9871</td>
#       <td id="T_76115_row5_col2" class="data row5 col2" >0.9330</td>
#       <td id="T_76115_row5_col3" class="data row5 col3" >0.9370</td>
#       <td id="T_76115_row5_col4" class="data row5 col4" >0.9327</td>
#       <td id="T_76115_row5_col5" class="data row5 col5" >0.8652</td>
#       <td id="T_76115_row5_col6" class="data row5 col6" >0.8695</td>
#     </tr>
#     <tr>
#       <th id="T_76115_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_76115_row6_col0" class="data row6 col0" >0.9286</td>
#       <td id="T_76115_row6_col1" class="data row6 col1" >0.9762</td>
#       <td id="T_76115_row6_col2" class="data row6 col2" >0.9286</td>
#       <td id="T_76115_row6_col3" class="data row6 col3" >0.9300</td>
#       <td id="T_76115_row6_col4" class="data row6 col4" >0.9286</td>
#       <td id="T_76115_row6_col5" class="data row6 col5" >0.8572</td>
#       <td id="T_76115_row6_col6" class="data row6 col6" >0.8584</td>
#     </tr>
#     <tr>
#       <th id="T_76115_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_76115_row7_col0" class="data row7 col0" >0.9596</td>
#       <td id="T_76115_row7_col1" class="data row7 col1" >0.9836</td>
#       <td id="T_76115_row7_col2" class="data row7 col2" >0.9596</td>
#       <td id="T_76115_row7_col3" class="data row7 col3" >0.9600</td>
#       <td id="T_76115_row7_col4" class="data row7 col4" >0.9597</td>
#       <td id="T_76115_row7_col5" class="data row7 col5" >0.9192</td>
#       <td id="T_76115_row7_col6" class="data row7 col6" >0.9195</td>
#     </tr>
#     <tr>
#       <th id="T_76115_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_76115_row8_col0" class="data row8 col0" >0.9372</td>
#       <td id="T_76115_row8_col1" class="data row8 col1" >0.9805</td>
#       <td id="T_76115_row8_col2" class="data row8 col2" >0.9372</td>
#       <td id="T_76115_row8_col3" class="data row8 col3" >0.9397</td>
#       <td id="T_76115_row8_col4" class="data row8 col4" >0.9372</td>
#       <td id="T_76115_row8_col5" class="data row8 col5" >0.8746</td>
#       <td id="T_76115_row8_col6" class="data row8 col6" >0.8769</td>
#     </tr>
#     <tr>
#       <th id="T_76115_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_76115_row9_col0" class="data row9 col0" >0.9507</td>
#       <td id="T_76115_row9_col1" class="data row9 col1" >0.9751</td>
#       <td id="T_76115_row9_col2" class="data row9 col2" >0.9507</td>
#       <td id="T_76115_row9_col3" class="data row9 col3" >0.9511</td>
#       <td id="T_76115_row9_col4" class="data row9 col4" >0.9507</td>
#       <td id="T_76115_row9_col5" class="data row9 col5" >0.9013</td>
#       <td id="T_76115_row9_col6" class="data row9 col6" >0.9016</td>
#     </tr>
#     <tr>
#       <th id="T_76115_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_76115_row10_col0" class="data row10 col0" >0.9432</td>
#       <td id="T_76115_row10_col1" class="data row10 col1" >0.9799</td>
#       <td id="T_76115_row10_col2" class="data row10 col2" >0.9432</td>
#       <td id="T_76115_row10_col3" class="data row10 col3" >0.9452</td>
#       <td id="T_76115_row10_col4" class="data row10 col4" >0.9432</td>
#       <td id="T_76115_row10_col5" class="data row10 col5" >0.8865</td>
#       <td id="T_76115_row10_col6" class="data row10 col6" >0.8883</td>
#     </tr>
#     <tr>
#       <th id="T_76115_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_76115_row11_col0" class="data row11 col0" >0.0205</td>
#       <td id="T_76115_row11_col1" class="data row11 col1" >0.0074</td>
#       <td id="T_76115_row11_col2" class="data row11 col2" >0.0205</td>
#       <td id="T_76115_row11_col3" class="data row11 col3" >0.0190</td>
#       <td id="
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# <style type="text/css">
# </style>
# <table id="T_0380a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0380a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0380a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_0380a_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_0380a_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_0380a_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_0380a_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_0380a_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_0380a_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0380a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0380a_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_0380a_row0_col1" class="data row0 col1" >0.9948</td>
#       <td id="T_0380a_row0_col2" class="data row0 col2" >0.9947</td>
#       <td id="T_0380a_row0_col3" class="data row0 col3" >0.9948</td>
#       <td id="T_0380a_row0_col4" class="data row0 col4" >0.9948</td>
#       <td id="T_0380a_row0_col5" class="data row0 col5" >0.9948</td>
#       <td id="T_0380a_row0_col6" class="data row0 col6" >0.9896</td>
#       <td id="T_0380a_row0_col7" class="data row0 col7" >0.9896</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_513f4_row10_col0, #T_513f4_row10_col1, #T_513f4_row10_col2, #T_513f4_row10_col3, #T_513f4_row10_col4, #T_513f4_row10_col5, #T_513f4_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_513f4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_513f4_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_513f4_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_513f4_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_513f4_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_513f4_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_513f4_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_513f4_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_513f4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_513f4_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_513f4_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_513f4_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_513f4_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_513f4_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_513f4_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_513f4_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_513f4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_513f4_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_513f4_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_513f4_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_513f4_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_513f4_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_513f4_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_513f4_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_513f4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_513f4_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_513f4_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_513f4_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_513f4_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_513f4_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_513f4_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_513f4_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_513f4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_513f4_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_513f4_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_513f4_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_513f4_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_513f4_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_513f4_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_513f4_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_513f4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_513f4_row4_col0" class="data row4 col0" >0.9866</td>
#       <td id="T_513f4_row4_col1" class="data row4 col1" >0.9994</td>
#       <td id="T_513f4_row4_col2" class="data row4 col2" >0.9866</td>
#       <td id="T_513f4_row4_col3" class="data row4 col3" >0.9867</td>
#       <td id="T_513f4_row4_col4" class="data row4 col4" >0.9866</td>
#       <td id="T_513f4_row4_col5" class="data row4 col5" >0.9732</td>
#       <td id="T_513f4_row4_col6" class="data row4 col6" >0.9732</td>
#     </tr>
#     <tr>
#       <th id="T_513f4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_513f4_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_513f4_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_513f4_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_513f4_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_513f4_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_513f4_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_513f4_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_513f4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_513f4_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_513f4_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_513f4_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_513f4_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_513f4_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_513f4_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_513f4_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_513f4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_513f4_row7_col0" class="data row7 col0" >0.9776</td>
#       <td id="T_513f4_row7_col1" class="data row7 col1" >0.9952</td>
#       <td id="T_513f4_row7_col2" class="data row7 col2" >0.9776</td>
#       <td id="T_513f4_row7_col3" class="data row7 col3" >0.9776</td>
#       <td id="T_513f4_row7_col4" class="data row7 col4" >0.9776</td>
#       <td id="T_513f4_row7_col5" class="data row7 col5" >0.9551</td>
#       <td id="T_513f4_row7_col6" class="data row7 col6" >0.9551</td>
#     </tr>
#     <tr>
#       <th id="T_513f4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_513f4_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_513f4_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_513f4_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_513f4_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_513f4_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_513f4_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_513f4_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_513f4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_513f4_row9_col0" class="data row9 col0" >0.9955</td>
#       <td id="T_513f4_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_513f4_row9_col2" class="data row9 col2" >0.9955</td>
#       <td id="T_513f4_row9_col3" class="data row9 col3" >0.9956</td>
#       <td id="T_513f4_row9_col4" class="data row9 col4" >0.9955</td>
#       <td id="T_513f4_row9_col5" class="data row9 col5" >0.9910</td>
#       <td id="T_513f4_row9_col6" class="data row9 col6" >0.9911</td>
#     </tr>
#     <tr>
#       <th id="T_513f4_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_513f4_row10_col0" class="data row10 col0" >0.9960</td>
#       <td id="T_513f4_row10_col1" class="data row10 col1" >0.9995</td>
#       <td id="T_513f4_row10_col2" class="data row10 col2" >0.9960</td>
#       <td id="T_513f4_row10_col3" class="data row10 col3" >0.9960</td>
#       <td id="T_513f4_row10_col4" class="data row10 col4" >0.9960</td>
#       <td id="T_513f4_row10_col5" class="data row10 col5" >0.9919</td>
#       <td id="T_513f4_row10_col6" class="data row10 col6" >0.9919</td>
#     </tr>
#     <tr>
#       <th id="T_513f4_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_513f4_row11_col0" class="data row11 col0" >0.0073</td>
#       <td id="T_513f4_row11_col1" class="data row11 col1" >0.0014</td>
#       <td id="T_513f4_row11_col2" class="data row11 col2" >0.0073</td>
#       <td id="T_513f4_row11_col3" class="data row11 col3" >0.0073</td>
#       <td id="
# Processing:   0%|          | 0/6 [00:00<?, ?it/s]
# <style type="text/css">
# #T_a5465_row10_col0, #T_a5465_row10_col1, #T_a5465_row10_col2, #T_a5465_row10_col3, #T_a5465_row10_col4, #T_a5465_row10_col5, #T_a5465_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a5465" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5465_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a5465_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a5465_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a5465_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a5465_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a5465_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a5465_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5465_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5465_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_a5465_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_a5465_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_a5465_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_a5465_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_a5465_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_a5465_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a5465_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a5465_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_a5465_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_a5465_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_a5465_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_a5465_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_a5465_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_a5465_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a5465_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a5465_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_a5465_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_a5465_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_a5465_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_a5465_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_a5465_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_a5465_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a5465_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a5465_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_a5465_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_a5465_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_a5465_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_a5465_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_a5465_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_a5465_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a5465_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a5465_row4_col0" class="data row4 col0" >0.9866</td>
#       <td id="T_a5465_row4_col1" class="data row4 col1" >0.9994</td>
#       <td id="T_a5465_row4_col2" class="data row4 col2" >0.9866</td>
#       <td id="T_a5465_row4_col3" class="data row4 col3" >0.9867</td>
#       <td id="T_a5465_row4_col4" class="data row4 col4" >0.9866</td>
#       <td id="T_a5465_row4_col5" class="data row4 col5" >0.9732</td>
#       <td id="T_a5465_row4_col6" class="data row4 col6" >0.9732</td>
#     </tr>
#     <tr>
#       <th id="T_a5465_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a5465_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_a5465_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_a5465_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_a5465_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_a5465_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_a5465_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_a5465_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a5465_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a5465_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_a5465_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_a5465_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_a5465_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_a5465_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_a5465_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_a5465_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a5465_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a5465_row7_col0" class="data row7 col0" >0.9776</td>
#       <td id="T_a5465_row7_col1" class="data row7 col1" >0.9952</td>
#       <td id="T_a5465_row7_col2" class="data row7 col2" >0.9776</td>
#       <td id="T_a5465_row7_col3" class="data row7 col3" >0.9776</td>
#       <td id="T_a5465_row7_col4" class="data row7 col4" >0.9776</td>
#       <td id="T_a5465_row7_col5" class="data row7 col5" >0.9551</td>
#       <td id="T_a5465_row7_col6" class="data row7 col6" >0.9551</td>
#     </tr>
#     <tr>
#       <th id="T_a5465_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a5465_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_a5465_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_a5465_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_a5465_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_a5465_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_a5465_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_a5465_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a5465_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a5465_row9_col0" class="data row9 col0" >0.9910</td>
#       <td id="T_a5465_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_a5465_row9_col2" class="data row9 col2" >0.9910</td>
#       <td id="T_a5465_row9_col3" class="data row9 col3" >0.9912</td>
#       <td id="T_a5465_row9_col4" class="data row9 col4" >0.9910</td>
#       <td id="T_a5465_row9_col5" class="data row9 col5" >0.9820</td>
#       <td id="T_a5465_row9_col6" class="data row9 col6" >0.9822</td>
#     </tr>
#     <tr>
#       <th id="T_a5465_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_a5465_row10_col0" class="data row10 col0" >0.9955</td>
#       <td id="T_a5465_row10_col1" class="data row10 col1" >0.9995</td>
#       <td id="T_a5465_row10_col2" class="data row10 col2" >0.9955</td>
#       <td id="T_a5465_row10_col3" class="data row10 col3" >0.9955</td>
#       <td id="T_a5465_row10_col4" class="data row10 col4" >0.9955</td>
#       <td id="T_a5465_row10_col5" class="data row10 col5" >0.9910</td>
#       <td id="T_a5465_row10_col6" class="data row10 col6" >0.9910</td>
#     </tr>
#     <tr>
#       <th id="T_a5465_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_a5465_row11_col0" class="data row11 col0" >0.0075</td>
#       <td id="T_a5465_row11_col1" class="data row11 col1" >0.0014</td>
#       <td id="T_a5465_row11_col2" class="data row11 col2" >0.0075</td>
#       <td id="T_a5465_row11_col3" class="data row11 col3" >0.0075</td>
#       <td id="
# Processing:   0%|          | 0/6 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_1b570" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b570_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1b570_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1b570_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_1b570_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_1b570_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_1b570_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_1b570_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_1b570_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b570_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b570_row0_col0" class="data row0 col0" >Voting Classifier</td>
#       <td id="T_1b570_row0_col1" class="data row0 col1" >0.9948</td>
#       <td id="T_1b570_row0_col2" class="data row0 col2" >0.9989</td>
#       <td id="T_1b570_row0_col3" class="data row0 col3" >0.9948</td>
#       <td id="T_1b570_row0_col4" class="data row0 col4" >0.9948</td>
#       <td id="T_1b570_row0_col5" class="data row0 col5" >0.9948</td>
#       <td id="T_1b570_row0_col6" class="data row0 col6" >0.9896</td>
#       <td id="T_1b570_row0_col7" class="data row0 col7" >0.9896</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_d3349" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3349_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d3349_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_d3349_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_d3349_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_d3349_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_d3349_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_d3349_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_d3349_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3349_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d3349_row0_col0" class="data row0 col0" >Stacking Classifier</td>
#       <td id="T_d3349_row0_col1" class="data row0 col1" >0.9948</td>
#       <td id="T_d3349_row0_col2" class="data row0 col2" >0.9989</td>
#       <td id="T_d3349_row0_col3" class="data row0 col3" >0.9948</td>
#       <td id="T_d3349_row0_col4" class="data row0 col4" >0.9948</td>
#       <td id="T_d3349_row0_col5" class="data row0 col5" >0.9948</td>
#       <td id="T_d3349_row0_col6" class="data row0 col6" >0.9896</td>
#       <td id="T_d3349_row0_col7" class="data row0 col7" >0.9896</td>
#     </tr>
#   </tbody>
# </table>
